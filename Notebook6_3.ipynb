# %% [markdown]
# <a href="https://colab.research.google.com/github/Resteves147/CSCI_167/blob/main/Notebook6_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 6.3: Stochastic gradient descent**
#
# This notebook investigates gradient descent and stochastic gradient descent and recreates figure 6.5 from the book
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap

# %%
# Let's create our training data of 30 pairs {x_i, y_i}
# We'll try to fit the Gabor model to these data
data = np.array([[-1.920e+00,-1.422e+01,1.490e+00,-1.940e+00,-2.389e+00,-5.090e+00,
                 -8.861e+00,3.578e+00,-6.010e+00,-6.995e+00,3.634e+00,8.743e-01,
                 -1.096e+01,4.073e-01,-9.467e+00,8.560e+00,1.062e+01,-1.729e-01,
                  1.040e+01,-1.261e+01,1.574e-01,-1.304e+01,-2.156e+00,-1.210e+01,
                 -1.119e+01,2.902e+00,-8.220e+00,-1.179e+01,-8.391e+00,-4.505e+00],
                  [-1.051e+00,-2.482e-02,8.896e-01,-4.943e-01,-9.371e-01,4.306e-01,
                  9.577e-03,-7.944e-02 ,1.624e-01,-2.682e-01,-3.129e-01,8.303e-01,
                  -2.365e-02,5.098e-01,-2.777e-01,3.367e-01,1.927e-01,-2.222e-01,
                  6.352e-02,6.888e-03,3.224e-02,1.091e-02,-5.706e-01,-5.258e-02,
                  -3.666e-02,1.709e-01,-4.805e-02,2.008e-01,-1.904e-01,5.952e-01]])

# %%
# Let's define our model
def model(phi,x):
  sin_component = np.sin(phi[0] + 0.06 * phi[1] * x)
  gauss_component = np.exp(-(phi[0] + 0.06 * phi[1] * x) * (phi[0] + 0.06 * phi[1] * x) / 32)
  y_pred= sin_component * gauss_component
  return y_pred

# %%
# Draw model
def draw_model(data,model,phi,title=None):
  x_model = np.arange(-15,15,0.1)
  y_model = model(phi,x_model)

  fix, ax = plt.subplots()
  ax.plot(data[0,:],data[1,:],'bo')
  ax.plot(x_model,y_model,'m-')
  ax.set_xlim([-15,15]);ax.set_ylim([-1,1])
  ax.set_xlabel('x'); ax.set_ylabel('y')
  if title is not None:
    ax.set_title(title)
  plt.show()

# %%
# Initialize the parameters and draw the model
phi = np.zeros((2,1))
phi[0] =  -5     # Horizontal offset
phi[1] =  25     # Frequency
draw_model(data,model,phi, "Initial parameters")

# %% [markdown]
# Now let's compute the sum of squares loss for the training data

# %%
def compute_loss(data_x, data_y, model, phi):
  # TODO -- Write this function -- replace the line below
  # TODO -- First make model predictions from data x
  y_pred = model(phi, data_x)
  # TODO -- Then compute the squared difference between the predictions and true y values
  squared_difference = (y_pred - data_y) ** 2
  # TODO -- Then sum them all and return
  loss = np.sum(squared_difference)

  return loss

# %% [markdown]
# Let's just test that we got that right

# %%
loss = compute_loss(data[0,:],data[1,:],model,np.array([[0.6],[-0.2]]))
print('Your loss = %3.3f, Correct loss = %3.3f'%(loss, 16.419))
# Out:
# Your loss = 16.419, Correct loss = 16.419

# %% [markdown]
# Now let's plot the whole loss function

# %%
def draw_loss_function(compute_loss, data,  model, phi_iters = None):
  # Define pretty colormap
  my_colormap_vals_hex =('2a0902', '2b0a03', '2c0b04', '2d0c05', '2e0c06', '2f0d07', '300d08', '310e09', '320f0a', '330f0b', '34100b', '35110c', '36110d', '37120e', '38120f', '39130f', '3a1410', '3b1411', '3c1511', '3d1612', '3e1613', '3f1713', '401714', '411814', '421915', '431915', '451a16', '461b16', '471b17', '481c17', '491d18', '4a1d18', '4b1e19', '4c1f19', '4d1f1a', '4e201b', '50211b', '51211c', '52221c', '53231d', '54231d', '55241e', '56251e', '57261f', '58261f', '592720', '5b2821', '5c2821', '5d2922', '5e2a22', '5f2b23', '602b23', '612c24', '622d25', '632e25', '652e26', '662f26', '673027', '683027', '693128', '6a3229', '6b3329', '6c342a', '6d342a', '6f352b', '70362c', '71372c', '72372d', '73382e', '74392e', '753a2f', '763a2f', '773b30', '783c31', '7a3d31', '7b3e32', '7c3e33', '7d3f34', '7e4034', '7f4135', '804236', '814236', '824337', '834438', '854538', '864639', '87473a', '88473a', '89483b', '8a493c', '8b4a3c', '8c4b3d', '8d4c3e', '8e4c3f', '8f4d3f', '904e40', '924f41', '935041', '945142', '955243', '965343', '975444', '985545', '995646', '9a5746', '9b5847', '9c5948', '9d5a49', '9e5a49', 'a05b4a', 'a15c4b', 'a25d4b', 'a35e4c', 'a45f4d', 'a5604e', 'a6614e', 'a7624f', 'a86350', 'aa6451', 'ab6552', 'ac6552', 'ad6653', 'ae6754', 'af6855', 'b06956', 'b16a57', 'b26b58', 'b36c59', 'b46d59', 'b56e5a', 'b66f5b', 'b7705c', 'b8715d', 'b9725d', 'bb735e', 'bc745f', 'bd7560', 'be7661', 'bf7762', 'c07862', 'c17963', 'c27b64', 'c37d66', 'c47e67', 'c57f68', 'c68068', 'c78169', 'c8826a', 'ca836b', 'cb846c', 'cc856d', 'cd876e', 'ce886f', 'cf8970', 'd08a71', 'd18b72', 'd28c73', 'd38e74', 'd48f75', 'd59076', 'd69177', 'd79278', 'd89379', 'd9957a', 'da967b', 'db977c', 'dc987d', 'dd997e', 'de9a7f', 'df9b80', 'e09c81', 'e19d82', 'e29f83', 'e3a084', 'e4a185', 'e5a286', 'e6a387', 'e7a488', 'e8a68a', 'e9a78b', 'eaa88c', 'eba98d', 'ecaa8e', 'edac8f', 'eead90', 'efae91', 'f0b092', 'f1b193', 'f2b294', 'f3b495', 'f4b596', 'f5b697', 'f6b798', 'f7b99a', 'f8ba9b', 'f9bb9c', 'fabc9d', 'fbbd9e', 'fcbf9f', 'fcc0a1', 'fdc1a2', 'fdc3a3', 'fec4a4', 'fec5a5', 'ffc6a6', 'ffc8a8', 'ffc9a9', 'ffcaaa', 'ffccab', 'ffcdac', 'ffcead', 'ffd0af', 'ffd1b0', 'ffd2b1', 'ffd4b2', 'ffd5b3', 'ffd6b5', 'ffd8b6', 'ffd9b7', 'ffdbb8', 'ffdcba', 'ffddbb', 'ffdfbc', 'ffe0bd', 'ffe2be', 'ffe3c0', 'ffe4c1', 'ffe6c2', 'ffe7c3', 'ffe9c5', 'ffeac6', 'ffebc7', 'ffedc9', 'ffeeca', 'fff0cb', 'fff1cc', 'fff3ce', 'fff4cf', 'fff6d0', 'fff7d1', 'fff9d3', 'fffad4', 'fffcd5', 'fffdd7', 'fffddd8', 'ffffd9')
  my_colormap_vals_dec = np.array([int(element,base=16) for element in my_colormap_vals_hex])
  r = np.floor(my_colormap_vals_dec/(256*256))
  g = np.floor((my_colormap_vals_dec - r *256 *256)/256)
  b = np.floor(my_colormap_vals_dec - r * 256 *256 - g * 256)
  my_colormap = ListedColormap(np.vstack((r,g,b)).transpose()/255.0)

  # Make grid of offset/frequency values to plot
  offsets_mesh, freqs_mesh = np.meshgrid(np.arange(-10,10.0,0.1), np.arange(2.5,22.5,0.1))
  loss_mesh = np.zeros_like(freqs_mesh)
  # Compute loss for every set of parameters
  for idslope, slope in np.ndenumerate(freqs_mesh):
     loss_mesh[idslope] = compute_loss(data[0,:], data[1,:], model, np.array([[offsets_mesh[idslope]], [slope]]))

  fig,ax = plt.subplots()
  fig.set_size_inches(8,8)
  ax.contourf(offsets_mesh,freqs_mesh,loss_mesh,256,cmap=my_colormap)
  ax.contour(offsets_mesh,freqs_mesh,loss_mesh,20,colors=['#80808080'])
  if phi_iters is not None:
    ax.plot(phi_iters[0,:], phi_iters[1,:],'go-')
  ax.set_ylim([2.5,22.5])
  ax.set_xlabel('Offset $\phi_{0}$'); ax.set_ylabel(r'Frequency, $\phi_{1}$')
  plt.show()

  #Keep getting Syntax warning, couldnt not generate function
# Out:
# <>:24: SyntaxWarning: invalid escape sequence '\p'
# <>:24: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipython-input-2559516844.py:24: SyntaxWarning: invalid escape sequence '\p'
#   ax.set_xlabel('Offset $\phi_{0}$'); ax.set_ylabel(r'Frequency, $\phi_{1}$')

# %%
draw_loss_function(compute_loss, data, model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1570500234.py in <cell line: 0>()
# ----> 1 draw_loss_function(compute_loss, data, model)
#
# /tmp/ipython-input-3566006623.py in draw_loss_function(compute_loss, data, model, phi_iters)
#       2   # Define pretty colormap
#       3   my_colormap_vals_hex =('2a0902', '2b0a03', '2c0b04', '2d0c05', '2e0c06', '2f0d07', '300d08', '310e09', '320f0a', '330f0b', '34100b', '35110c', '36110d', '37120e', '38120f', '39130f', '3a1410', '3b1411', '3c1511', '3d1612', '3e1613', '3f1713', '401714', '411814', '421915', '431915', '451a16', '461b16', '471b17', '481c17', '491d18', '4a1d18', '4b1e19', '4c1f19', '4d1f1a', '4e201b', '50211b', '51211c', '52221c', '53231d', '54231d', '55241e', '56251e', '57261f', '58261f'...
# ----> 4   my_colormap_vals_dec = np.array([int(element,base=16) for element in my_colormap_vals_hex])
#       5   r = np.floor(my_colormap_vals_dec/(256*256))
#       6   g = np.floor((my_colormap_vals_dec - r *256 *256)/256)
#
# ValueError: invalid literal for int() with base 16: 'eea d90'

# %% [markdown]
# Now let's compute the gradient vector for a given set of parameters:
#
# \begin{equation}
# \frac{\partial L}{\partial \boldsymbol\phi} = \begin{bmatrix}\frac{\partial L}{\partial \phi_0} \\\frac{\partial L}{\partial \phi_1} \end{bmatrix}.
# \end{equation}

# %%
# These came from writing out the expression for the sum of squares loss and taking the
# derivative with respect to phi0 and phi1. It was a lot of hassle to get it right!
def gabor_deriv_phi0(data_x,data_y,phi0, phi1):
    x = 0.06 * phi1 * data_x + phi0
    y = data_y
    cos_component = np.cos(x)
    sin_component = np.sin(x)
    gauss_component = np.exp(-0.5 * x *x / 16)
    deriv = cos_component * gauss_component - sin_component * gauss_component * x / 16
    deriv = 2* deriv * (sin_component * gauss_component - y)
    return np.sum(deriv)

def gabor_deriv_phi1(data_x, data_y,phi0, phi1):
    x = 0.06 * phi1 * data_x + phi0
    y = data_y
    cos_component = np.cos(x)
    sin_component = np.sin(x)
    gauss_component = np.exp(-0.5 * x *x / 16)
    deriv = 0.06 * data_x * cos_component * gauss_component - 0.06 * data_x*sin_component * gauss_component * x / 16
    deriv = 2*deriv * (sin_component * gauss_component - y)
    return np.sum(deriv)

def compute_gradient(data_x, data_y, phi):
    dl_dphi0 = gabor_deriv_phi0(data_x, data_y, phi[0],phi[1])
    dl_dphi1 = gabor_deriv_phi1(data_x, data_y, phi[0],phi[1])
    # Return the gradient
    return np.array([[dl_dphi0],[dl_dphi1]])

# %% [markdown]
# We can check we got this right using a trick known as **finite differences**.  If we evaluate the function and then change one of the parameters by a very small amount and normalize by that amount, we get an approximation to the gradient, so:
#
# \begin{align}
# \frac{\partial L}{\partial \phi_{0}}&\approx & \frac{L[\phi_0+\delta, \phi_1]-L[\phi_0, \phi_1]}{\delta}\\
# \frac{\partial L}{\partial \phi_{1}}&\approx & \frac{L[\phi_0, \phi_1+\delta]-L[\phi_0, \phi_1]}{\delta}
# \end{align}
#
# We can't do this when there are many parameters;  for a million parameters, we would have to evaluate the loss function two million times, and usually computing the gradients directly is much more efficient.

# %%
# Compute the gradient using your function
gradient = compute_gradient(data[0,:],data[1,:], phi)
print("Your gradients: (%3.3f,%3.3f)"%(gradient[0],gradient[1]))
# Approximate the gradients with finite differences
delta = 0.0001
dl_dphi0_est = (compute_loss(data[0,:],data[1,:],model,phi+np.array([[delta],[0]])) - \
                    compute_loss(data[0,:],data[1,:],model,phi))/delta
dl_dphi1_est = (compute_loss(data[0,:],data[1,:],model,phi+np.array([[0],[delta]])) - \
                    compute_loss(data[0,:],data[1,:],model,phi))/delta
print("Approx gradients: (%3.3f,%3.3f)"%(dl_dphi0_est,dl_dphi1_est))
# Out:
# Your gradients: (3.344,0.519)
# Approx gradients: (3.344,0.519)
# /tmp/ipython-input-330192272.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Your gradients: (%3.3f,%3.3f)"%(gradient[0],gradient[1]))

# %% [markdown]
# Now we are ready to perform gradient descent.  We'll need to use our line search routine from Notebook 6.1, which I've reproduced here plus the helper function loss_function_1D that converts from a 2D problem to a 1D problem

# %%
def loss_function_1D(dist_prop, data, model, phi_start, gradient):
  # Return the loss after moving this far
  return compute_loss(data[0,:], data[1,:], model, phi_start+ gradient * dist_prop)

def line_search(data, model, phi, gradient, thresh=.00001, max_dist = 0.1, max_iter = 15, verbose=False):
    # Initialize four points along the range we are going to search
    a = 0
    b = 0.33 * max_dist
    c = 0.66 * max_dist
    d = 1.0 * max_dist
    n_iter = 0

    # While we haven't found the minimum closely enough
    while np.abs(b-c) > thresh and n_iter < max_iter:
        # Increment iteration counter (just to prevent an infinite loop)
        n_iter = n_iter+1
        # Calculate all four points
        lossa = loss_function_1D(a, data, model, phi,gradient)
        lossb = loss_function_1D(b, data, model, phi,gradient)
        lossc = loss_function_1D(c, data, model, phi,gradient)
        lossd = loss_function_1D(d, data, model, phi,gradient)

        if verbose:
          print('Iter %d, a=%3.3f, b=%3.3f, c=%3.3f, d=%3.3f'%(n_iter, a,b,c,d))
          print('a %f, b%f, c%f, d%f'%(lossa,lossb,lossc,lossd))

        # Rule #1 If point A is less than points B, C, and D then change B,C,D so they are half their current distance from A
        if np.argmin((lossa,lossb,lossc,lossd))==0:
          b = a+ (b-a)/2
          c = a+ (c-a)/2
          d = a+ (d-a)/2
          continue;

        # Rule #2 If point b is less than point c then
        #                     point d becomes point c, and
        #                     point b becomes 1/3 between a and new d
        #                     point c becomes 2/3 between a and new d
        if lossb < lossc:
          d = c
          b = a+ (d-a)/3
          c = a+ 2*(d-a)/3
          continue

        # Rule #2 If point c is less than point b then
        #                     point a becomes point b, and
        #                     point b becomes 1/3 between new a and d
        #                     point c becomes 2/3 between new a and d
        a = b
        b = a+ (d-a)/3
        c = a+ 2*(d-a)/3

    # Return average of two middle points
    return (b+c)/2.0

# %%
def gradient_descent_step(phi, data,  model):
  # Step 1:  Compute the gradient
  gradient = compute_gradient(data[0,:],data[1,:], phi)
  # Step 2:  Update the parameters -- note we want to search in the negative (downhill direction)
  alpha = line_search(data, model, phi, gradient*-1, max_dist = 2.0)
  phi = phi - alpha * gradient
  return phi

# %%
# Initialize the parameters
n_steps = 21
phi_all = np.zeros((2,n_steps+1))
phi_all[0,0] = -1.5
phi_all[1,0] = 8.5

# Measure loss and draw initial model
loss =  compute_loss(data[0,:], data[1,:], model, phi_all[:,0:1])
draw_model(data,model,phi_all[:,0:1], "Initial parameters, Loss = %f"%(loss))

for c_step in range (n_steps):
  # Do gradient descent step
  phi_all[:,c_step+1:c_step+2] = gradient_descent_step(phi_all[:,c_step:c_step+1],data, model)
  # Measure loss and draw model every 4th step
  if c_step % 4 == 0:
    loss =  compute_loss(data[0,:], data[1,:], model, phi_all[:,c_step+1:c_step+2])
    draw_model(data,model,phi_all[:,c_step+1], "Iteration %d, loss = %f"%(c_step+1,loss))

draw_loss_function(compute_loss, data, model,phi_all)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2975342403.py in <cell line: 0>()
#      17     draw_model(data,model,phi_all[:,c_step+1], "Iteration %d, loss = %f"%(c_step+1,loss))
#      18
# ---> 19 draw_loss_function(compute_loss, data, model,phi_all)
#
# /tmp/ipython-input-2559516844.py in draw_loss_function(compute_loss, data, model, phi_iters)
#      17   fig,ax = plt.subplots()
#      18   fig.set_size_inches(8,8)
# ---> 19   ax.contourf(offsets_mesh,freqs_mesh,loss_mesh,256,cmap=my_colormap)
#      20   ax.contour(offsets_mesh,freqs_mesh,loss_mesh,20,colors=['#80808080'])
#      21   if phi_iters is not None:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6758         """
#    6759         kwargs['filled'] = True
# -> 6760         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6761         self._request_autoscale_view()
#    6762         return contours
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, colorizer, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     751         self.labelCValues = []
#     752
# --> 753         self.set_cmap(cmap)
#     754         if norm is not None:
#     755             self.set_norm(norm)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in set_cmap(self, cmap)
#     406         cmap : `.Colormap` or str or None
#     407         """
# --> 408         self.cmap = cmap
#     409
#     410     @property
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in cmap(self, cmap)
#     392     @cmap.setter
#     393     def cmap(self, cmap):
# --> 394         self._colorizer.cmap = cmap
#     395
#     396     def get_cmap(self):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in cmap(self, cmap)
#     245     @cmap.setter
#     246     def cmap(self, cmap):
# --> 247         self._set_cmap(cmap)
#     248
#     249     def set_clim(self, vmin=None, vmax=None):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in _set_cmap(self, cmap)
#     237         self._cmap = cm._ensure_cmap(cmap)
#     238         if not in_init:
# --> 239             self.changed()  # Things are not set up properly yet.
#     240
#     241     @property
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in changed(self)
#     284         callbackSM listeners to the 'changed' signal.
#     285         """
# --> 286         self.callbacks.process('changed')
#     287         self.stale = True
#     288
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     364                 except Exception as exc:
#     365                     if self.exception_handler is not None:
# --> 366                         self.exception_handler(exc)
#     367                     else:
#     368                         raise
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     359             if func is not None:
#     360                 try:
# --> 361                     func(*args, **kwargs)
#     362                 # this does not capture KeyboardInterrupt, SystemExit,
#     363                 # and GeneratorExit
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/contour.py in changed(self)
#     955     def changed(self):
#     956         if not hasattr(self, "cvalues"):
# --> 957             self._process_colors()  # Sets cvalues.
#     958         # Force an autoscale immediately because self.to_rgba() calls
#     959         # autoscale_None() internally with the data passed to it,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/contour.py in _process_colors(self)
#    1112         else:
#    1113             self.cvalues = self.layers
# -> 1114         self.norm.autoscale_None(self.levels)
#    1115         self.set_array(self.cvalues)
#    1116         self.update_scalarmappable()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in autoscale_None(self, A)
#    2338
#    2339         if self.vmin is None and A.size:
# -> 2340             self.vmin = A.min()
#    2341         if self.vmax is None and A.size:
#    2342             self.vmax = A.max()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in vmin(self, value)
#    2181         if value != self._vmin:
#    2182             self._vmin = value
# -> 2183             self._changed()
#    2184
#    2185     @property
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in _changed(self)
#    2209         callback listeners to the 'changed' signal.
#    2210         """
# -> 2211         self.callbacks.process('changed')
#    2212
#    2213     @staticmethod
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     364                 except Exception as exc:
#     365                     if self.exception_handler is not None:
# --> 366                         self.exception_handler(exc)
#     367                     else:
#     368                         raise
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     359             if func is not None:
#     360                 try:
# --> 361                     func(*args, **kwargs)
#     362                 # this does not capture KeyboardInterrupt, SystemExit,
#     363                 # and GeneratorExit
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in changed(self)
#     284         callbackSM listeners to the 'changed' signal.
#     285         """
# --> 286         self.callbacks.process('changed')
#     287         self.stale = True
#     288
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     364                 except Exception as exc:
#     365                     if self.exception_handler is not None:
# --> 366                         self.exception_handler(exc)
#     367                     else:
#     368                         raise
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     359             if func is not None:
#     360                 try:
# --> 361                     func(*args, **kwargs)
#     362                 # this does not capture KeyboardInterrupt, SystemExit,
#     363                 # and GeneratorExit
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/contour.py in changed(self)
#     960         # so if vmin/vmax are not set yet, this would override them with
#     961         # content from *cvalues* rather than levels like we want
# --> 962         self.norm.autoscale_None(self.levels)
#     963         self.set_array(self.cvalues)
#     964         self.update_scalarmappable()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in autoscale_None(self, A)
#    2340             self.vmin = A.min()
#    2341         if self.vmax is None and A.size:
# -> 2342             self.vmax = A.max()
#    2343
#    2344     def scaled(self):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in vmax(self, value)
#    2192         if value != self._vmax:
#    2193             self._vmax = value
# -> 2194             self._changed()
#    2195
#    2196     @property
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in _changed(self)
#    2209         callback listeners to the 'changed' signal.
#    2210         """
# -> 2211         self.callbacks.process('changed')
#    2212
#    2213     @staticmethod
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     364                 except Exception as exc:
#     365                     if self.exception_handler is not None:
# --> 366                         self.exception_handler(exc)
#     367                     else:
#     368                         raise
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     359             if func is not None:
#     360                 try:
# --> 361                     func(*args, **kwargs)
#     362                 # this does not capture KeyboardInterrupt, SystemExit,
#     363                 # and GeneratorExit
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in changed(self)
#     284         callbackSM listeners to the 'changed' signal.
#     285         """
# --> 286         self.callbacks.process('changed')
#     287         self.stale = True
#     288
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     364                 except Exception as exc:
#     365                     if self.exception_handler is not None:
# --> 366                         self.exception_handler(exc)
#     367                     else:
#     368                         raise
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     359             if func is not None:
#     360                 try:
# --> 361                     func(*args, **kwargs)
#     362                 # this does not capture KeyboardInterrupt, SystemExit,
#     363                 # and GeneratorExit
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/contour.py in changed(self)
#     962         self.norm.autoscale_None(self.levels)
#     963         self.set_array(self.cvalues)
# --> 964         self.update_scalarmappable()
#     965         alphas = np.broadcast_to(self.get_alpha(), len(self.cvalues))
#     966         for label, cv, alpha in zip(self.labelTexts, self.labelCValues, alphas):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/collections.py in update_scalarmappable(self)
#     930                 # pcolormesh, scatter, maybe others flatten their _A
#     931                 self._alpha = self._alpha.reshape(self._A.shape)
# --> 932             self._mapped_colors = self.to_rgba(self._A, self._alpha)
#     933
#     934         if self._face_is_mapped:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in to_rgba(self, x, alpha, bytes, norm)
#     354
#     355         """
# --> 356         return self._colorizer.to_rgba(x, alpha=alpha, bytes=bytes, norm=norm)
#     357
#     358     def get_clim(self):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in to_rgba(self, x, alpha, bytes, norm)
#     156         if norm:
#     157             x = self.norm(x)
# --> 158         rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     159         return rgba
#     160
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in __call__(self, X, alpha, bytes)
#     737         RGBA values with a shape of ``X.shape + (4, )``.
#     738         """
# --> 739         rgba, mask = self._get_rgba_and_mask(X, alpha=alpha, bytes=bytes)
#     740         if not np.iterable(X):
#     741             rgba = tuple(rgba)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in _get_rgba_and_mask(self, X, alpha, bytes)
#     768         """
#     769         if not self._isinit:
# --> 770             self._init()
#     771
#     772         xa = np.array(X, copy=True)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in _init(self)
#    1217     def _init(self):
#    1218         self._lut = np.zeros((self.N + 3, 4), float)
# -> 1219         self._lut[:-3] = to_rgba_array(self.colors)
#    1220         self._isinit = True
#    1221         self._set_extremes()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     476             result[mask] = 0
#     477         if np.any((result < 0) | (result > 1)):
# --> 478             raise ValueError("RGBA values should be within 0-1 range")
#     479         return result
#     480     # Handle single values.
#
# ValueError: RGBA values should be within 0-1 range

# %%
# TODO Experiment with starting the optimization in the previous cell in different places
# and show that it heads to a local minimum if we don't start it in the right valley

# %%
def gradient_descent_step_fixed_learning_rate(phi, data, alpha):
  # TODO -- fill in this routine so that we take a fixed size step of size alpha without using line search

  # Compute the gradient
  gradient = compute_gradient(data[0,:], data[1,:], phi)

  # Update the parameters with a fixed learning rate
  phi = phi - alpha * gradient

  return phi

# %%
# Initialize the parameters
n_steps = 21
phi_all = np.zeros((2,n_steps+1))
phi_all[0,0] = -1.5
phi_all[1,0] = 8.5

# Measure loss and draw initial model
loss =  compute_loss(data[0,:], data[1,:], model, phi_all[:,0:1])
draw_model(data,model,phi_all[:,0:1], "Initial parameters, Loss = %f"%(loss))

for c_step in range (n_steps):
  # Do gradient descent step
  phi_all[:,c_step+1:c_step+2] = gradient_descent_step_fixed_learning_rate(phi_all[:,c_step:c_step+1],data, alpha =0.2)
  # Measure loss and draw model every 4th step
  if c_step % 4 == 0:
    loss =  compute_loss(data[0,:], data[1,:], model, phi_all[:,c_step+1:c_step+2])
    draw_model(data,model,phi_all[:,c_step+1], "Iteration %d, loss = %f"%(c_step+1,loss))

draw_loss_function(compute_loss, data, model,phi_all)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-211488557.py in <cell line: 0>()
#      17     draw_model(data,model,phi_all[:,c_step+1], "Iteration %d, loss = %f"%(c_step+1,loss))
#      18
# ---> 19 draw_loss_function(compute_loss, data, model,phi_all)
#
# /tmp/ipython-input-2559516844.py in draw_loss_function(compute_loss, data, model, phi_iters)
#      17   fig,ax = plt.subplots()
#      18   fig.set_size_inches(8,8)
# ---> 19   ax.contourf(offsets_mesh,freqs_mesh,loss_mesh,256,cmap=my_colormap)
#      20   ax.contour(offsets_mesh,freqs_mesh,loss_mesh,20,colors=['#80808080'])
#      21   if phi_iters is not None:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6758         """
#    6759         kwargs['filled'] = True
# -> 6760         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6761         self._request_autoscale_view()
#    6762         return contours
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, colorizer, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     751         self.labelCValues = []
#     752
# --> 753         self.set_cmap(cmap)
#     754         if norm is not None:
#     755             self.set_norm(norm)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in set_cmap(self, cmap)
#     406         cmap : `.Colormap` or str or None
#     407         """
# --> 408         self.cmap = cmap
#     409
#     410     @property
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in cmap(self, cmap)
#     392     @cmap.setter
#     393     def cmap(self, cmap):
# --> 394         self._colorizer.cmap = cmap
#     395
#     396     def get_cmap(self):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in cmap(self, cmap)
#     245     @cmap.setter
#     246     def cmap(self, cmap):
# --> 247         self._set_cmap(cmap)
#     248
#     249     def set_clim(self, vmin=None, vmax=None):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in _set_cmap(self, cmap)
#     237         self._cmap = cm._ensure_cmap(cmap)
#     238         if not in_init:
# --> 239             self.changed()  # Things are not set up properly yet.
#     240
#     241     @property
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in changed(self)
#     284         callbackSM listeners to the 'changed' signal.
#     285         """
# --> 286         self.callbacks.process('changed')
#     287         self.stale = True
#     288
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     364                 except Exception as exc:
#     365                     if self.exception_handler is not None:
# --> 366                         self.exception_handler(exc)
#     367                     else:
#     368                         raise
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     359             if func is not None:
#     360                 try:
# --> 361                     func(*args, **kwargs)
#     362                 # this does not capture KeyboardInterrupt, SystemExit,
#     363                 # and GeneratorExit
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/contour.py in changed(self)
#     955     def changed(self):
#     956         if not hasattr(self, "cvalues"):
# --> 957             self._process_colors()  # Sets cvalues.
#     958         # Force an autoscale immediately because self.to_rgba() calls
#     959         # autoscale_None() internally with the data passed to it,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/contour.py in _process_colors(self)
#    1112         else:
#    1113             self.cvalues = self.layers
# -> 1114         self.norm.autoscale_None(self.levels)
#    1115         self.set_array(self.cvalues)
#    1116         self.update_scalarmappable()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in autoscale_None(self, A)
#    2338
#    2339         if self.vmin is None and A.size:
# -> 2340             self.vmin = A.min()
#    2341         if self.vmax is None and A.size:
#    2342             self.vmax = A.max()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in vmin(self, value)
#    2181         if value != self._vmin:
#    2182             self._vmin = value
# -> 2183             self._changed()
#    2184
#    2185     @property
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in _changed(self)
#    2209         callback listeners to the 'changed' signal.
#    2210         """
# -> 2211         self.callbacks.process('changed')
#    2212
#    2213     @staticmethod
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     364                 except Exception as exc:
#     365                     if self.exception_handler is not None:
# --> 366                         self.exception_handler(exc)
#     367                     else:
#     368                         raise
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     359             if func is not None:
#     360                 try:
# --> 361                     func(*args, **kwargs)
#     362                 # this does not capture KeyboardInterrupt, SystemExit,
#     363                 # and GeneratorExit
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in changed(self)
#     284         callbackSM listeners to the 'changed' signal.
#     285         """
# --> 286         self.callbacks.process('changed')
#     287         self.stale = True
#     288
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     364                 except Exception as exc:
#     365                     if self.exception_handler is not None:
# --> 366                         self.exception_handler(exc)
#     367                     else:
#     368                         raise
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     359             if func is not None:
#     360                 try:
# --> 361                     func(*args, **kwargs)
#     362                 # this does not capture KeyboardInterrupt, SystemExit,
#     363                 # and GeneratorExit
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/contour.py in changed(self)
#     960         # so if vmin/vmax are not set yet, this would override them with
#     961         # content from *cvalues* rather than levels like we want
# --> 962         self.norm.autoscale_None(self.levels)
#     963         self.set_array(self.cvalues)
#     964         self.update_scalarmappable()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in autoscale_None(self, A)
#    2340             self.vmin = A.min()
#    2341         if self.vmax is None and A.size:
# -> 2342             self.vmax = A.max()
#    2343
#    2344     def scaled(self):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in vmax(self, value)
#    2192         if value != self._vmax:
#    2193             self._vmax = value
# -> 2194             self._changed()
#    2195
#    2196     @property
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in _changed(self)
#    2209         callback listeners to the 'changed' signal.
#    2210         """
# -> 2211         self.callbacks.process('changed')
#    2212
#    2213     @staticmethod
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     364                 except Exception as exc:
#     365                     if self.exception_handler is not None:
# --> 366                         self.exception_handler(exc)
#     367                     else:
#     368                         raise
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     359             if func is not None:
#     360                 try:
# --> 361                     func(*args, **kwargs)
#     362                 # this does not capture KeyboardInterrupt, SystemExit,
#     363                 # and GeneratorExit
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in changed(self)
#     284         callbackSM listeners to the 'changed' signal.
#     285         """
# --> 286         self.callbacks.process('changed')
#     287         self.stale = True
#     288
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     364                 except Exception as exc:
#     365                     if self.exception_handler is not None:
# --> 366                         self.exception_handler(exc)
#     367                     else:
#     368                         raise
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     359             if func is not None:
#     360                 try:
# --> 361                     func(*args, **kwargs)
#     362                 # this does not capture KeyboardInterrupt, SystemExit,
#     363                 # and GeneratorExit
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/contour.py in changed(self)
#     962         self.norm.autoscale_None(self.levels)
#     963         self.set_array(self.cvalues)
# --> 964         self.update_scalarmappable()
#     965         alphas = np.broadcast_to(self.get_alpha(), len(self.cvalues))
#     966         for label, cv, alpha in zip(self.labelTexts, self.labelCValues, alphas):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/collections.py in update_scalarmappable(self)
#     930                 # pcolormesh, scatter, maybe others flatten their _A
#     931                 self._alpha = self._alpha.reshape(self._A.shape)
# --> 932             self._mapped_colors = self.to_rgba(self._A, self._alpha)
#     933
#     934         if self._face_is_mapped:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in to_rgba(self, x, alpha, bytes, norm)
#     354
#     355         """
# --> 356         return self._colorizer.to_rgba(x, alpha=alpha, bytes=bytes, norm=norm)
#     357
#     358     def get_clim(self):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in to_rgba(self, x, alpha, bytes, norm)
#     156         if norm:
#     157             x = self.norm(x)
# --> 158         rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     159         return rgba
#     160
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in __call__(self, X, alpha, bytes)
#     737         RGBA values with a shape of ``X.shape + (4, )``.
#     738         """
# --> 739         rgba, mask = self._get_rgba_and_mask(X, alpha=alpha, bytes=bytes)
#     740         if not np.iterable(X):
#     741             rgba = tuple(rgba)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in _get_rgba_and_mask(self, X, alpha, bytes)
#     768         """
#     769         if not self._isinit:
# --> 770             self._init()
#     771
#     772         xa = np.array(X, copy=True)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in _init(self)
#    1217     def _init(self):
#    1218         self._lut = np.zeros((self.N + 3, 4), float)
# -> 1219         self._lut[:-3] = to_rgba_array(self.colors)
#    1220         self._isinit = True
#    1221         self._set_extremes()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     476             result[mask] = 0
#     477         if np.any((result < 0) | (result > 1)):
# --> 478             raise ValueError("RGBA values should be within 0-1 range")
#     479         return result
#     480     # Handle single values.
#
# ValueError: RGBA values should be within 0-1 range

# %%
# TODO Experiment with the learning rate, alpha.
# What happens if you set it too large?]
#becomes too large in the gradient descent, loss increase and not decrease
# What happens if you set it too small?
# more iterations needed because too small

# %%
def stochastic_gradient_descent_step(phi, data, alpha, batch_size):
  # TODO -- fill in this routine so that we take a fixed size step of size alpha but only using a subset (batch) of the data
  # at each step
  # You can use the function np.random.permutation to generate a random permutation of the n_data = data.shape[1] indices
  # and then just choose the first n=batch_size of these indices.  Then compute the gradient update
  # from just the data with these indices.   More properly, you should sample without replacement, but this will do for now.

  n_data = data.shape[1]
  # Generate a random permutation of indices
  shuffled_indices = np.random.permutation(n_data)
  # Select the first batch_size indices
  batch_indices = shuffled_indices[:batch_size]
  # Select the batch of data
  data_batch = data[:, batch_indices]

  # Compute the gradient using the batch data
  gradient = compute_gradient(data_batch[0,:], data_batch[1,:], phi)

  # Update the parameters with a fixed learning rate
  phi = phi - alpha * gradient

  return phi

# %%
# Set the random number generator so you always get same numbers (disable if you don't want this)
np.random.seed(1)
# Initialize the parameters
n_steps = 41
phi_all = np.zeros((2,n_steps+1))
phi_all[0,0] = 3.5
phi_all[1,0] = 6.5

# Define learning rate schedule parameters
initial_alpha = 0.8
beta = 0.9 # Factor to reduce learning rate by
M = 10 # Reduce learning rate every M iterations
alpha = initial_alpha

# Measure loss and draw initial model
loss =  compute_loss(data[0,:], data[1,:], model, phi_all[:,0:1])
draw_model(data,model,phi_all[:,0:1], "Initial parameters, Loss = %f"%(loss))

for c_step in range (n_steps):
  # Update learning rate according to schedule
  if (c_step + 1) % M == 0:
      alpha = alpha * beta
      print(f"Reducing learning rate to {alpha} at step {c_step+1}")

  # Do gradient descent step
  phi_all[:,c_step+1:c_step+2] = stochastic_gradient_descent_step(phi_all[:,c_step:c_step+1],data, alpha =alpha, batch_size=5)
  # Measure loss and draw model every 8th step
  if c_step % 8 == 0:
    loss =  compute_loss(data[0,:], data[1,:], model, phi_all[:,c_step+1:c_step+2])
    draw_model(data,model,phi_all[:,c_step+1], "Iteration %d, loss = %f"%(c_step+1,loss))

draw_loss_function(compute_loss, data, model,phi_all)
# Out:
# Reducing learning rate to 0.7200000000000001 at step 10
# Reducing learning rate to 0.6480000000000001 at step 20
# Reducing learning rate to 0.5832000000000002 at step 30
# Reducing learning rate to 0.5248800000000001 at step 40
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2861220529.py in <cell line: 0>()
#      30     draw_model(data,model,phi_all[:,c_step+1], "Iteration %d, loss = %f"%(c_step+1,loss))
#      31
# ---> 32 draw_loss_function(compute_loss, data, model,phi_all)
#
# /tmp/ipython-input-2559516844.py in draw_loss_function(compute_loss, data, model, phi_iters)
#      17   fig,ax = plt.subplots()
#      18   fig.set_size_inches(8,8)
# ---> 19   ax.contourf(offsets_mesh,freqs_mesh,loss_mesh,256,cmap=my_colormap)
#      20   ax.contour(offsets_mesh,freqs_mesh,loss_mesh,20,colors=['#80808080'])
#      21   if phi_iters is not None:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6758         """
#    6759         kwargs['filled'] = True
# -> 6760         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6761         self._request_autoscale_view()
#    6762         return contours
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, colorizer, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     751         self.labelCValues = []
#     752
# --> 753         self.set_cmap(cmap)
#     754         if norm is not None:
#     755             self.set_norm(norm)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in set_cmap(self, cmap)
#     406         cmap : `.Colormap` or str or None
#     407         """
# --> 408         self.cmap = cmap
#     409
#     410     @property
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in cmap(self, cmap)
#     392     @cmap.setter
#     393     def cmap(self, cmap):
# --> 394         self._colorizer.cmap = cmap
#     395
#     396     def get_cmap(self):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in cmap(self, cmap)
#     245     @cmap.setter
#     246     def cmap(self, cmap):
# --> 247         self._set_cmap(cmap)
#     248
#     249     def set_clim(self, vmin=None, vmax=None):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in _set_cmap(self, cmap)
#     237         self._cmap = cm._ensure_cmap(cmap)
#     238         if not in_init:
# --> 239             self.changed()  # Things are not set up properly yet.
#     240
#     241     @property
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in changed(self)
#     284         callbackSM listeners to the 'changed' signal.
#     285         """
# --> 286         self.callbacks.process('changed')
#     287         self.stale = True
#     288
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     364                 except Exception as exc:
#     365                     if self.exception_handler is not None:
# --> 366                         self.exception_handler(exc)
#     367                     else:
#     368                         raise
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     359             if func is not None:
#     360                 try:
# --> 361                     func(*args, **kwargs)
#     362                 # this does not capture KeyboardInterrupt, SystemExit,
#     363                 # and GeneratorExit
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/contour.py in changed(self)
#     955     def changed(self):
#     956         if not hasattr(self, "cvalues"):
# --> 957             self._process_colors()  # Sets cvalues.
#     958         # Force an autoscale immediately because self.to_rgba() calls
#     959         # autoscale_None() internally with the data passed to it,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/contour.py in _process_colors(self)
#    1112         else:
#    1113             self.cvalues = self.layers
# -> 1114         self.norm.autoscale_None(self.levels)
#    1115         self.set_array(self.cvalues)
#    1116         self.update_scalarmappable()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in autoscale_None(self, A)
#    2338
#    2339         if self.vmin is None and A.size:
# -> 2340             self.vmin = A.min()
#    2341         if self.vmax is None and A.size:
#    2342             self.vmax = A.max()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in vmin(self, value)
#    2181         if value != self._vmin:
#    2182             self._vmin = value
# -> 2183             self._changed()
#    2184
#    2185     @property
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in _changed(self)
#    2209         callback listeners to the 'changed' signal.
#    2210         """
# -> 2211         self.callbacks.process('changed')
#    2212
#    2213     @staticmethod
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     364                 except Exception as exc:
#     365                     if self.exception_handler is not None:
# --> 366                         self.exception_handler(exc)
#     367                     else:
#     368                         raise
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     359             if func is not None:
#     360                 try:
# --> 361                     func(*args, **kwargs)
#     362                 # this does not capture KeyboardInterrupt, SystemExit,
#     363                 # and GeneratorExit
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in changed(self)
#     284         callbackSM listeners to the 'changed' signal.
#     285         """
# --> 286         self.callbacks.process('changed')
#     287         self.stale = True
#     288
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     364                 except Exception as exc:
#     365                     if self.exception_handler is not None:
# --> 366                         self.exception_handler(exc)
#     367                     else:
#     368                         raise
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     359             if func is not None:
#     360                 try:
# --> 361                     func(*args, **kwargs)
#     362                 # this does not capture KeyboardInterrupt, SystemExit,
#     363                 # and GeneratorExit
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/contour.py in changed(self)
#     960         # so if vmin/vmax are not set yet, this would override them with
#     961         # content from *cvalues* rather than levels like we want
# --> 962         self.norm.autoscale_None(self.levels)
#     963         self.set_array(self.cvalues)
#     964         self.update_scalarmappable()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in autoscale_None(self, A)
#    2340             self.vmin = A.min()
#    2341         if self.vmax is None and A.size:
# -> 2342             self.vmax = A.max()
#    2343
#    2344     def scaled(self):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in vmax(self, value)
#    2192         if value != self._vmax:
#    2193             self._vmax = value
# -> 2194             self._changed()
#    2195
#    2196     @property
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in _changed(self)
#    2209         callback listeners to the 'changed' signal.
#    2210         """
# -> 2211         self.callbacks.process('changed')
#    2212
#    2213     @staticmethod
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     364                 except Exception as exc:
#     365                     if self.exception_handler is not None:
# --> 366                         self.exception_handler(exc)
#     367                     else:
#     368                         raise
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     359             if func is not None:
#     360                 try:
# --> 361                     func(*args, **kwargs)
#     362                 # this does not capture KeyboardInterrupt, SystemExit,
#     363                 # and GeneratorExit
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in changed(self)
#     284         callbackSM listeners to the 'changed' signal.
#     285         """
# --> 286         self.callbacks.process('changed')
#     287         self.stale = True
#     288
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     364                 except Exception as exc:
#     365                     if self.exception_handler is not None:
# --> 366                         self.exception_handler(exc)
#     367                     else:
#     368                         raise
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     359             if func is not None:
#     360                 try:
# --> 361                     func(*args, **kwargs)
#     362                 # this does not capture KeyboardInterrupt, SystemExit,
#     363                 # and GeneratorExit
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/contour.py in changed(self)
#     962         self.norm.autoscale_None(self.levels)
#     963         self.set_array(self.cvalues)
# --> 964         self.update_scalarmappable()
#     965         alphas = np.broadcast_to(self.get_alpha(), len(self.cvalues))
#     966         for label, cv, alpha in zip(self.labelTexts, self.labelCValues, alphas):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/collections.py in update_scalarmappable(self)
#     930                 # pcolormesh, scatter, maybe others flatten their _A
#     931                 self._alpha = self._alpha.reshape(self._A.shape)
# --> 932             self._mapped_colors = self.to_rgba(self._A, self._alpha)
#     933
#     934         if self._face_is_mapped:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in to_rgba(self, x, alpha, bytes, norm)
#     354
#     355         """
# --> 356         return self._colorizer.to_rgba(x, alpha=alpha, bytes=bytes, norm=norm)
#     357
#     358     def get_clim(self):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colorizer.py in to_rgba(self, x, alpha, bytes, norm)
#     156         if norm:
#     157             x = self.norm(x)
# --> 158         rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     159         return rgba
#     160
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in __call__(self, X, alpha, bytes)
#     737         RGBA values with a shape of ``X.shape + (4, )``.
#     738         """
# --> 739         rgba, mask = self._get_rgba_and_mask(X, alpha=alpha, bytes=bytes)
#     740         if not np.iterable(X):
#     741             rgba = tuple(rgba)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in _get_rgba_and_mask(self, X, alpha, bytes)
#     768         """
#     769         if not self._isinit:
# --> 770             self._init()
#     771
#     772         xa = np.array(X, copy=True)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in _init(self)
#    1217     def _init(self):
#    1218         self._lut = np.zeros((self.N + 3, 4), float)
# -> 1219         self._lut[:-3] = to_rgba_array(self.colors)
#    1220         self._isinit = True
#    1221         self._set_extremes()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     476             result[mask] = 0
#     477         if np.any((result < 0) | (result > 1)):
# --> 478             raise ValueError("RGBA values should be within 0-1 range")
#     479         return result
#     480     # Handle single values.
#
# ValueError: RGBA values should be within 0-1 range

# %%
# TODO -- Experiment with different learning rates, starting points, batch sizes, number of steps.  Get a feel for this.

# %%
# TODO -- Add a learning rate schedule.  Reduce the learning rate by a factor of beta every M iterations
