# %% [markdown]
# <a href="https://colab.research.google.com/github/Resteves147/CSCI_167/blob/main/Copy_of_10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-_lsiz4uz
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-_lsiz4uz
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=56abb398869166bd638faf63c25cd9c3a13e7f4818082b063c992158b25a94b4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-eh7yxwyd/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(60, 10)
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.894784, train error 76.28,  val loss 1.887506, percent error 73.20
# Epoch     1, train loss 1.572629, train error 59.67,  val loss 1.583505, percent error 60.00
# Epoch     2, train loss 1.346937, train error 54.85,  val loss 1.359573, percent error 56.40
# Epoch     3, train loss 1.306412, train error 54.12,  val loss 1.311548, percent error 55.60
# Epoch     4, train loss 1.187801, train error 47.83,  val loss 1.207830, percent error 51.30
# Epoch     5, train loss 1.233417, train error 50.95,  val loss 1.237720, percent error 51.90
# Epoch     6, train loss 1.092696, train error 44.20,  val loss 1.114293, percent error 47.90
# Epoch     7, train loss 0.989790, train error 39.58,  val loss 1.030503, percent error 44.50
# Epoch     8, train loss 0.906964, train error 35.45,  val loss 0.941527, percent error 39.20
# Epoch     9, train loss 0.847048, train error 34.38,  val loss 0.904769, percent error 37.60
# Epoch    10, train loss 0.754400, train error 30.20,  val loss 0.810451, percent error 32.60
# Epoch    11, train loss 0.756228, train error 30.82,  val loss 0.848248, percent error 35.70
# Epoch    12, train loss 0.649634, train error 24.28,  val loss 0.735817, percent error 29.80
# Epoch    13, train loss 0.600123, train error 23.28,  val loss 0.702143, percent error 27.10
# Epoch    14, train loss 0.545559, train error 21.45,  val loss 0.635170, percent error 26.30
# Epoch    15, train loss 0.500471, train error 18.80,  val loss 0.593937, percent error 22.90
# Epoch    16, train loss 0.465175, train error 16.43,  val loss 0.554001, percent error 21.30
# Epoch    17, train loss 0.391001, train error 14.15,  val loss 0.498117, percent error 19.50
# Epoch    18, train loss 0.354365, train error 12.53,  val loss 0.467150, percent error 17.10
# Epoch    19, train loss 0.387191, train error 14.03,  val loss 0.491104, percent error 18.20
# Epoch    20, train loss 0.299566, train error 10.20,  val loss 0.440714, percent error 16.90
# Epoch    21, train loss 0.255857, train error 8.62,  val loss 0.402780, percent error 14.70
# Epoch    22, train loss 0.237734, train error 8.00,  val loss 0.385659, percent error 14.50
# Epoch    23, train loss 0.253054, train error 8.85,  val loss 0.411583, percent error 15.70
# Epoch    24, train loss 0.220285, train error 7.40,  val loss 0.368558, percent error 13.10
# Epoch    25, train loss 0.233131, train error 8.22,  val loss 0.390295, percent error 14.00
# Epoch    26, train loss 0.205230, train error 7.20,  val loss 0.358477, percent error 13.60
# Epoch    27, train loss 0.196817, train error 6.75,  val loss 0.378729, percent error 14.10
# Epoch    28, train loss 0.208334, train error 7.25,  val loss 0.402524, percent error 14.10
# Epoch    29, train loss 0.187744, train error 6.25,  val loss 0.384806, percent error 13.20
# Epoch    30, train loss 0.172416, train error 6.22,  val loss 0.372931, percent error 13.70
# Epoch    31, train loss 0.207401, train error 7.57,  val loss 0.405617, percent error 13.30
# Epoch    32, train loss 0.172061, train error 5.93,  val loss 0.377465, percent error 12.40
# Epoch    33, train loss 0.164042, train error 5.65,  val loss 0.355384, percent error 12.30
# Epoch    34, train loss 0.135719, train error 4.35,  val loss 0.345825, percent error 11.80
# Epoch    35, train loss 0.136270, train error 4.65,  val loss 0.367654, percent error 11.90
# Epoch    36, train loss 0.170840, train error 5.57,  val loss 0.393355, percent error 12.90
# Epoch    37, train loss 0.124691, train error 3.88,  val loss 0.354423, percent error 11.60
# Epoch    38, train loss 0.123924, train error 4.30,  val loss 0.354094, percent error 12.00
# Epoch    39, train loss 0.130297, train error 4.32,  val loss 0.365524, percent error 11.80
# Epoch    40, train loss 0.107122, train error 3.38,  val loss 0.348288, percent error 11.40
# Epoch    41, train loss 0.093726, train error 2.85,  val loss 0.350946, percent error 11.20
# Epoch    42, train loss 0.093213, train error 2.93,  val loss 0.342237, percent error 11.00
# Epoch    43, train loss 0.090272, train error 2.68,  val loss 0.364306, percent error 11.10
# Epoch    44, train loss 0.100583, train error 3.43,  val loss 0.371563, percent error 11.00
# Epoch    45, train loss 0.091417, train error 3.03,  val loss 0.372120, percent error 11.30
# Epoch    46, train loss 0.089488, train error 2.75,  val loss 0.353611, percent error 11.30
# Epoch    47, train loss 0.080841, train error 2.18,  val loss 0.356850, percent error 10.50
# Epoch    48, train loss 0.081241, train error 2.53,  val loss 0.362756, percent error 10.80
# Epoch    49, train loss 0.080621, train error 2.22,  val loss 0.373270, percent error 11.20
# Epoch    50, train loss 0.075715, train error 2.15,  val loss 0.369593, percent error 11.30
# Epoch    51, train loss 0.074745, train error 2.30,  val loss 0.368829, percent error 10.80
# Epoch    52, train loss 0.074740, train error 2.20,  val loss 0.380376, percent error 11.40
# Epoch    53, train loss 0.070672, train error 1.85,  val loss 0.366892, percent error 10.70
# Epoch    54, train loss 0.067763, train error 1.88,  val loss 0.365918, percent error 10.90
# Epoch    55, train loss 0.068368, train error 1.72,  val loss 0.381716, percent error 11.20
# Epoch    56, train loss 0.065128, train error 1.65,  val loss 0.364602, percent error 11.20
# Epoch    57, train loss 0.070553, train error 1.95,  val loss 0.383342, percent error 11.40
# Epoch    58, train loss 0.068874, train error 1.85,  val loss 0.379939, percent error 11.60
# Epoch    59, train loss 0.068213, train error 1.85,  val loss 0.381891, percent error 11.80
# Epoch    60, train loss 0.059398, train error 1.45,  val loss 0.375758, percent error 11.80
# Epoch    61, train loss 0.057995, train error 1.35,  val loss 0.385437, percent error 11.30
# Epoch    62, train loss 0.058290, train error 1.38,  val loss 0.383223, percent error 11.70
# Epoch    63, train loss 0.058767, train error 1.35,  val loss 0.382799, percent error 11.40
# Epoch    64, train loss 0.056705, train error 1.32,  val loss 0.386991, percent error 11.10
# Epoch    65, train loss 0.055791, train error 1.22,  val loss 0.385474, percent error 11.10
# Epoch    66, train loss 0.056392, train error 1.18,  val loss 0.388741, percent error 11.40
# Epoch    67, train loss 0.055292, train error 1.32,  val loss 0.393615, percent error 11.90
# Epoch    68, train loss 0.054267, train error 1.22,  val loss 0.398089, percent error 11.60
# Epoch    69, train loss 0.053196, train error 1.18,  val loss 0.395963, percent error 12.00
# Epoch    70, train loss 0.053088, train error 1.10,  val loss 0.391495, percent error 11.60
# Epoch    71, train loss 0.052490, train error 1.18,  val loss 0.400327, percent error 12.20
# Epoch    72, train loss 0.051273, train error 1.00,  val loss 0.397128, percent error 11.60
# Epoch    73, train loss 0.050746, train error 1.03,  val loss 0.396953, percent error 11.60
# Epoch    74, train loss 0.050922, train error 1.12,  val loss 0.401589, percent error 11.60
# Epoch    75, train loss 0.049526, train error 0.90,  val loss 0.398556, percent error 11.50
# Epoch    76, train loss 0.050958, train error 1.07,  val loss 0.403009, percent error 11.70
# Epoch    77, train loss 0.049101, train error 1.03,  val loss 0.408279, percent error 11.80
# Epoch    78, train loss 0.047842, train error 0.90,  val loss 0.405376, percent error 11.50
# Epoch    79, train loss 0.049572, train error 0.93,  val loss 0.407394, percent error 11.70
# Epoch    80, train loss 0.046513, train error 0.82,  val loss 0.403698, percent error 11.60
# Epoch    81, train loss 0.046211, train error 0.82,  val loss 0.407317, percent error 11.60
# Epoch    82, train loss 0.046597, train error 0.90,  val loss 0.408396, percent error 11.60
# Epoch    83, train loss 0.045808, train error 0.75,  val loss 0.406201, percent error 11.60
# Epoch    84, train loss 0.046052, train error 0.82,  val loss 0.408066, percent error 11.90
# Epoch    85, train loss 0.045665, train error 0.78,  val loss 0.412392, percent error 11.70
# Epoch    86, train loss 0.045372, train error 0.80,  val loss 0.412236, percent error 12.10
# Epoch    87, train loss 0.044893, train error 0.82,  val loss 0.410764, percent error 11.60
# Epoch    88, train loss 0.044741, train error 0.75,  val loss 0.409854, percent error 11.30
# Epoch    89, train loss 0.044476, train error 0.70,  val loss 0.412524, percent error 11.70
# Epoch    90, train loss 0.044270, train error 0.78,  val loss 0.413287, percent error 11.60
# Epoch    91, train loss 0.043757, train error 0.68,  val loss 0.414406, percent error 11.60
# Epoch    92, train loss 0.043696, train error 0.68,  val loss 0.415868, percent error 11.90
# Epoch    93, train loss 0.043678, train error 0.72,  val loss 0.415679, percent error 12.00
# Epoch    94, train loss 0.042962, train error 0.65,  val loss 0.414837, percent error 11.50
# Epoch    95, train loss 0.043130, train error 0.70,  val loss 0.417459, percent error 12.00
# Epoch    96, train loss 0.042769, train error 0.75,  val loss 0.418424, percent error 11.40
# Epoch    97, train loss 0.042763, train error 0.72,  val loss 0.421853, percent error 11.80
# Epoch    98, train loss 0.042630, train error 0.68,  val loss 0.416642, percent error 12.10
# Epoch    99, train loss 0.042991, train error 0.68,  val loss 0.420833, percent error 12.00
