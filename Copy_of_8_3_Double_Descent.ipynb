# %% [markdown]
# <a href="https://colab.research.google.com/github/Resteves147/CSCI_167/blob/main/Copy_of_8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-jcnunoct
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-jcnunoct
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=b0cada32edb084f0169b97592f4f3f54632fca136404c87217deeca1e75174e2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7n4img_a/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
#   When the hidden variable approaches zero
#
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
#
# around 10-20 hidden variables
#
# 3. At what capacity do you expect the maximum of the double descent curve to appear?
#
# Around 40-60 hidden variables

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.289457, train error 89.78,  test loss 2.291931, test error 89.55
# Epoch   100, train loss 1.895043, train error 70.47,  test loss 1.747671, test error 68.88
# Epoch   200, train loss 1.883746, train error 69.90,  test loss 1.738403, test error 67.80
# Epoch   300, train loss 1.869165, train error 68.50,  test loss 1.713549, test error 66.45
# Epoch   400, train loss 1.866584, train error 68.18,  test loss 1.698991, test error 66.45
# Epoch   500, train loss 1.860661, train error 67.47,  test loss 1.702565, test error 66.28
# Epoch   600, train loss 1.868754, train error 68.53,  test loss 1.715330, test error 66.10
# Epoch   700, train loss 1.859398, train error 67.88,  test loss 1.697863, test error 66.25
# Epoch   800, train loss 1.861277, train error 68.15,  test loss 1.699371, test error 66.78
# Epoch   900, train loss 1.859307, train error 67.55,  test loss 1.700958, test error 66.45
# Training model with   4 hidden variables
# Epoch     0, train loss 2.243737, train error 83.07,  test loss 2.230129, test error 83.20
# Epoch   100, train loss 1.702599, train error 61.55,  test loss 1.496713, test error 57.60
# Epoch   200, train loss 1.698783, train error 62.60,  test loss 1.513426, test error 59.35
# Epoch   300, train loss 1.687079, train error 61.85,  test loss 1.501068, test error 58.92
# Epoch   400, train loss 1.684079, train error 61.60,  test loss 1.500312, test error 57.75
# Epoch   500, train loss 1.680839, train error 61.42,  test loss 1.499211, test error 58.25
# Epoch   600, train loss 1.680247, train error 61.33,  test loss 1.501356, test error 57.97
# Epoch   700, train loss 1.678606, train error 61.35,  test loss 1.501317, test error 58.15
# Epoch   800, train loss 1.677762, train error 61.20,  test loss 1.498928, test error 57.92
# Epoch   900, train loss 1.677984, train error 61.45,  test loss 1.498968, test error 58.60
# Training model with   6 hidden variables
# Epoch     0, train loss 2.196540, train error 81.28,  test loss 2.166642, test error 80.00
# Epoch   100, train loss 1.663613, train error 58.33,  test loss 1.510297, test error 57.78
# Epoch   200, train loss 1.632213, train error 57.42,  test loss 1.487673, test error 56.88
# Epoch   300, train loss 1.623976, train error 57.15,  test loss 1.489701, test error 56.25
# Epoch   400, train loss 1.597972, train error 55.55,  test loss 1.440333, test error 53.45
# Epoch   500, train loss 1.568799, train error 53.90,  test loss 1.385785, test error 51.45
# Epoch   600, train loss 1.558005, train error 54.05,  test loss 1.394147, test error 52.47
# Epoch   700, train loss 1.544905, train error 52.83,  test loss 1.378471, test error 51.92
# Epoch   800, train loss 1.539043, train error 52.78,  test loss 1.381175, test error 52.38
# Epoch   900, train loss 1.538636, train error 53.28,  test loss 1.383571, test error 52.58
# Training model with   8 hidden variables
# Epoch     0, train loss 2.225297, train error 86.10,  test loss 2.211909, test error 85.68
# Epoch   100, train loss 1.620579, train error 58.17,  test loss 1.454359, test error 56.72
# Epoch   200, train loss 1.591530, train error 56.30,  test loss 1.453972, test error 56.10
# Epoch   300, train loss 1.578120, train error 56.10,  test loss 1.438160, test error 56.28
# Epoch   400, train loss 1.574763, train error 56.03,  test loss 1.459351, test error 57.05
# Epoch   500, train loss 1.566237, train error 56.17,  test loss 1.454296, test error 56.47
# Epoch   600, train loss 1.579319, train error 56.97,  test loss 1.457274, test error 56.67
# Epoch   700, train loss 1.563751, train error 55.72,  test loss 1.463353, test error 57.00
# Epoch   800, train loss 1.558248, train error 55.72,  test loss 1.460629, test error 57.15
# Epoch   900, train loss 1.556714, train error 55.12,  test loss 1.461608, test error 57.08
# Training model with  10 hidden variables
# Epoch     0, train loss 2.281797, train error 86.57,  test loss 2.274002, test error 86.10
# Epoch   100, train loss 1.576192, train error 54.83,  test loss 1.428232, test error 55.62
# Epoch   200, train loss 1.531488, train error 53.12,  test loss 1.408092, test error 53.17
# Epoch   300, train loss 1.509154, train error 52.42,  test loss 1.425589, test error 54.42
# Epoch   400, train loss 1.499537, train error 52.35,  test loss 1.430955, test error 54.80
# Epoch   500, train loss 1.490835, train error 52.03,  test loss 1.441339, test error 54.80
# Epoch   600, train loss 1.483021, train error 51.47,  test loss 1.448498, test error 54.70
# Epoch   700, train loss 1.479752, train error 51.42,  test loss 1.446718, test error 54.50
# Epoch   800, train loss 1.463131, train error 50.65,  test loss 1.455324, test error 55.25
# Epoch   900, train loss 1.454571, train error 50.62,  test loss 1.452928, test error 55.08
# Training model with  14 hidden variables
# Epoch     0, train loss 2.222465, train error 82.62,  test loss 2.200383, test error 81.85
# Epoch   100, train loss 1.424317, train error 47.78,  test loss 1.287345, test error 48.15
# Epoch   200, train loss 1.353961, train error 45.53,  test loss 1.303828, test error 49.28
# Epoch   300, train loss 1.328430, train error 45.17,  test loss 1.313648, test error 48.12
# Epoch   400, train loss 1.297040, train error 43.53,  test loss 1.337509, test error 48.08
# Epoch   500, train loss 1.287677, train error 43.92,  test loss 1.374846, test error 49.45
# Epoch   600, train loss 1.283391, train error 43.40,  test loss 1.370567, test error 48.70
# Epoch   700, train loss 1.276037, train error 44.10,  test loss 1.375202, test error 49.38
# Epoch   800, train loss 1.262665, train error 43.65,  test loss 1.387914, test error 48.97
# Epoch   900, train loss 1.260775, train error 43.35,  test loss 1.408972, test error 49.53
# Training model with  18 hidden variables
# Epoch     0, train loss 2.173363, train error 80.43,  test loss 2.151199, test error 80.40
# Epoch   100, train loss 1.393764, train error 46.38,  test loss 1.350671, test error 51.00
# Epoch   200, train loss 1.283352, train error 43.17,  test loss 1.311301, test error 48.92
# Epoch   300, train loss 1.226015, train error 41.50,  test loss 1.341683, test error 48.55
# Epoch   400, train loss 1.202640, train error 39.78,  test loss 1.366414, test error 48.92
# Epoch   500, train loss 1.166219, train error 38.92,  test loss 1.397042, test error 49.97
# Epoch   600, train loss 1.149751, train error 38.30,  test loss 1.447114, test error 50.33
# Epoch   700, train loss 1.127730, train error 38.50,  test loss 1.478875, test error 50.80
# Epoch   800, train loss 1.119925, train error 37.78,  test loss 1.530187, test error 51.22
# Epoch   900, train loss 1.118040, train error 37.80,  test loss 1.541421, test error 51.38
# Training model with  22 hidden variables
# Epoch     0, train loss 2.242160, train error 81.88,  test loss 2.232731, test error 81.10
# Epoch   100, train loss 1.259941, train error 42.42,  test loss 1.313105, test error 48.00
# Epoch   200, train loss 1.168390, train error 39.70,  test loss 1.363993, test error 49.10
# Epoch   300, train loss 1.106858, train error 37.30,  test loss 1.406706, test error 48.97
# Epoch   400, train loss 1.068749, train error 36.08,  test loss 1.479946, test error 50.95
# Epoch   500, train loss 1.038433, train error 35.12,  test loss 1.530064, test error 51.88
# Epoch   600, train loss 1.007789, train error 33.70,  test loss 1.570171, test error 51.58
# Epoch   700, train loss 0.998447, train error 33.75,  test loss 1.634827, test error 52.15
# Epoch   800, train loss 0.982967, train error 32.57,  test loss 1.658836, test error 51.53
# Epoch   900, train loss 0.986698, train error 33.55,  test loss 1.703742, test error 52.53
# Training model with  26 hidden variables
# Epoch     0, train loss 2.195113, train error 80.35,  test loss 2.173665, test error 79.85
# Epoch   100, train loss 1.201376, train error 40.33,  test loss 1.330583, test error 49.17
# Epoch   200, train loss 1.067744, train error 36.03,  test loss 1.414265, test error 50.72
# Epoch   300, train loss 0.974042, train error 32.18,  test loss 1.540612, test error 51.35
# Epoch   400, train loss 0.933629, train error 31.40,  test loss 1.665252, test error 52.00
# Epoch   500, train loss 0.904052, train error 30.10,  test loss 1.792806, test error 52.95
# Epoch   600, train loss 0.864656, train error 28.10,  test loss 1.851501, test error 52.90
# Epoch   700, train loss 0.845722, train error 28.40,  test loss 1.973299, test error 53.40
# Epoch   800, train loss 0.820749, train error 27.85,  test loss 2.029048, test error 53.22
# Epoch   900, train loss 0.819503, train error 27.47,  test loss 2.127237, test error 52.95
# Training model with  30 hidden variables
# Epoch     0, train loss 2.190848, train error 80.80,  test loss 2.175778, test error 80.72
# Epoch   100, train loss 1.122614, train error 37.20,  test loss 1.329123, test error 47.72
# Epoch   200, train loss 0.922231, train error 30.93,  test loss 1.566764, test error 51.45
# Epoch   300, train loss 0.805894, train error 26.57,  test loss 1.748471, test error 51.22
# Epoch   400, train loss 0.748153, train error 24.50,  test loss 1.929678, test error 52.22
# Epoch   500, train loss 0.739538, train error 24.85,  test loss 2.139987, test error 53.08
# Epoch   600, train loss 0.706962, train error 23.65,  test loss 2.285086, test error 54.40
# Epoch   700, train loss 0.660419, train error 22.28,  test loss 2.370042, test error 53.95
# Epoch   800, train loss 0.646240, train error 21.85,  test loss 2.553952, test error 53.72
# Epoch   900, train loss 0.628358, train error 21.47,  test loss 2.670830, test error 54.38
# Training model with  35 hidden variables
# Epoch     0, train loss 2.130696, train error 78.75,  test loss 2.084416, test error 78.40
# Epoch   100, train loss 1.029217, train error 33.40,  test loss 1.349758, test error 48.95
# Epoch   200, train loss 0.803941, train error 26.72,  test loss 1.637541, test error 50.92
# Epoch   300, train loss 0.711010, train error 24.07,  test loss 1.946461, test error 52.65
# Epoch   400, train loss 0.624981, train error 21.40,  test loss 2.261051, test error 54.38
# Epoch   500, train loss 0.588483, train error 19.12,  test loss 2.593834, test error 54.70
# Epoch   600, train loss 0.532077, train error 17.93,  test loss 2.837567, test error 54.88
# Epoch   700, train loss 0.510253, train error 16.82,  test loss 3.127107, test error 55.35
# Epoch   800, train loss 0.480006, train error 15.93,  test loss 3.376943, test error 54.92
# Epoch   900, train loss 0.467451, train error 15.80,  test loss 3.621454, test error 55.33
# Training model with  40 hidden variables
# Epoch     0, train loss 2.077527, train error 77.00,  test loss 2.037288, test error 78.25
# Epoch   100, train loss 0.914283, train error 29.75,  test loss 1.399705, test error 49.58
# Epoch   200, train loss 0.622897, train error 20.07,  test loss 1.921947, test error 52.42
# Epoch   300, train loss 0.506821, train error 17.28,  test loss 2.524839, test error 52.95
# Epoch   400, train loss 0.410612, train error 13.57,  test loss 3.212582, test error 55.80
# Epoch   500, train loss 0.374360, train error 12.50,  test loss 3.917482, test error 55.42
# Epoch   600, train loss 0.360228, train error 12.50,  test loss 4.581074, test error 55.72
# Epoch   700, train loss 0.335867, train error 11.95,  test loss 5.214424, test error 55.58
# Epoch   800, train loss 0.304009, train error 10.97,  test loss 5.770860, test error 56.58
# Epoch   900, train loss 0.367172, train error 12.62,  test loss 6.246168, test error 55.03
# Training model with  45 hidden variables
# Epoch     0, train loss 2.104267, train error 78.32,  test loss 2.058020, test error 77.25
# Epoch   100, train loss 0.813936, train error 25.35,  test loss 1.526743, test error 49.92
# Epoch   200, train loss 0.492400, train error 16.38,  test loss 2.195539, test error 52.67
# Epoch   300, train loss 0.319739, train error 10.20,  test loss 3.209559, test error 54.58
# Epoch   400, train loss 0.223508, train error 7.30,  test loss 4.297167, test error 55.42
# Epoch   500, train loss 0.282511, train error 10.25,  test loss 5.537617, test error 55.10
# Epoch   600, train loss 0.184671, train error 6.70,  test loss 6.639227, test error 55.83
# Epoch   700, train loss 0.017089, train error 0.00,  test loss 7.580981, test error 55.80
# Epoch   800, train loss 0.009522, train error 0.00,  test loss 8.358774, test error 56.35
# Epoch   900, train loss 0.006891, train error 0.00,  test loss 8.899351, test error 56.47
# Training model with  50 hidden variables
# Epoch     0, train loss 2.099334, train error 77.07,  test loss 2.090353, test error 79.05
# Epoch   100, train loss 0.710904, train error 22.38,  test loss 1.595180, test error 50.12
# Epoch   200, train loss 0.333024, train error 9.15,  test loss 2.762043, test error 54.85
# Epoch   300, train loss 0.156078, train error 3.62,  test loss 4.425910, test error 55.45
# Epoch   400, train loss 0.035181, train error 0.05,  test loss 6.175128, test error 57.28
# Epoch   500, train loss 0.014619, train error 0.00,  test loss 7.311956, test error 57.67
# Epoch   600, train loss 0.008869, train error 0.00,  test loss 8.040217, test error 57.88
# Epoch   700, train loss 0.006299, train error 0.00,  test loss 8.588820, test error 57.72
# Epoch   800, train loss 0.004828, train error 0.00,  test loss 9.027741, test error 57.80
# Epoch   900, train loss 0.003881, train error 0.00,  test loss 9.381048, test error 57.95
# Training model with  55 hidden variables
# Epoch     0, train loss 2.084118, train error 78.03,  test loss 2.005630, test error 76.22
# Epoch   100, train loss 0.632824, train error 18.55,  test loss 1.664231, test error 52.30
# Epoch   200, train loss 0.255535, train error 7.28,  test loss 3.083613, test error 55.10
# Epoch   300, train loss 0.049086, train error 0.18,  test loss 4.660214, test error 55.72
# Epoch   400, train loss 0.015933, train error 0.00,  test loss 5.772806, test error 55.72
# Epoch   500, train loss 0.009054, train error 0.00,  test loss 6.415548, test error 55.60
# Epoch   600, train loss 0.006115, train error 0.00,  test loss 6.886480, test error 55.65
# Epoch   700, train loss 0.004517, train error 0.00,  test loss 7.246956, test error 55.62
# Epoch   800, train loss 0.003555, train error 0.00,  test loss 7.536767, test error 55.62
# Epoch   900, train loss 0.002898, train error 0.00,  test loss 7.781954, test error 55.53
# Training model with  60 hidden variables
# Epoch     0, train loss 2.023847, train error 76.38,  test loss 1.954331, test error 75.80
# Epoch   100, train loss 0.532280, train error 16.22,  test loss 1.810182, test error 52.05
# Epoch   200, train loss 0.099517, train error 1.00,  test loss 3.507942, test error 54.90
# Epoch   300, train loss 0.019250, train error 0.00,  test loss 4.882391, test error 55.35
# Epoch   400, train loss 0.009522, train error 0.00,  test loss 5.591478, test error 55.45
# Epoch   500, train loss 0.006003, train error 0.00,  test loss 6.053745, test error 55.78
# Epoch   600, train loss 0.004326, train error 0.00,  test loss 6.398092, test error 55.70
# Epoch   700, train loss 0.003323, train error 0.00,  test loss 6.664757, test error 55.83
# Epoch   800, train loss 0.002678, train error 0.00,  test loss 6.889708, test error 55.62
# Epoch   900, train loss 0.002226, train error 0.00,  test loss 7.084417, test error 55.70
# Training model with  70 hidden variables
# Epoch     0, train loss 2.042094, train error 75.85,  test loss 1.994274, test error 75.20
# Epoch   100, train loss 0.367958, train error 10.55,  test loss 1.958705, test error 51.00
# Epoch   200, train loss 0.030427, train error 0.00,  test loss 3.520719, test error 52.60
# Epoch   300, train loss 0.010526, train error 0.00,  test loss 4.272217, test error 53.03
# Epoch   400, train loss 0.005937, train error 0.00,  test loss 4.706428, test error 53.15
# Epoch   500, train loss 0.004004, train error 0.00,  test loss 4.997972, test error 53.22
# Epoch   600, train loss 0.002963, train error 0.00,  test loss 5.222259, test error 53.45
# Epoch   700, train loss 0.002330, train error 0.00,  test loss 5.404010, test error 53.58
# Epoch   800, train loss 0.001906, train error 0.00,  test loss 5.558924, test error 53.62
# Epoch   900, train loss 0.001602, train error 0.00,  test loss 5.689692, test error 53.70
# Training model with  80 hidden variables
# Epoch     0, train loss 2.055409, train error 76.95,  test loss 2.024010, test error 77.40
# Epoch   100, train loss 0.247998, train error 4.85,  test loss 2.116993, test error 52.10
# Epoch   200, train loss 0.020419, train error 0.00,  test loss 3.413826, test error 52.05
# Epoch   300, train loss 0.008123, train error 0.00,  test loss 3.974587, test error 52.53
# Epoch   400, train loss 0.004766, train error 0.00,  test loss 4.304224, test error 52.47
# Epoch   500, train loss 0.003285, train error 0.00,  test loss 4.536408, test error 52.53
# Epoch   600, train loss 0.002465, train error 0.00,  test loss 4.718039, test error 52.62
# Epoch   700, train loss 0.001957, train error 0.00,  test loss 4.865389, test error 52.53
# Epoch   800, train loss 0.001610, train error 0.00,  test loss 4.987272, test error 52.60
# Epoch   900, train loss 0.001361, train error 0.00,  test loss 5.092931, test error 52.62
# Training model with  90 hidden variables
# Epoch     0, train loss 1.994928, train error 74.12,  test loss 1.935816, test error 74.85
# Epoch   100, train loss 0.146111, train error 1.30,  test loss 2.147289, test error 50.38
# Epoch   200, train loss 0.014595, train error 0.00,  test loss 3.232437, test error 51.03
# Epoch   300, train loss 0.006449, train error 0.00,  test loss 3.667853, test error 51.20
# Epoch   400, train loss 0.003936, train error 0.00,  test loss 3.935868, test error 51.50
# Epoch   500, train loss 0.002770, train error 0.00,  test loss 4.130825, test error 51.53
# Epoch   600, train loss 0.002105, train error 0.00,  test loss 4.282457, test error 51.40
# Epoch   700, train loss 0.001684, train error 0.00,  test loss 4.408343, test error 51.42
# Epoch   800, train loss 0.001393, train error 0.00,  test loss 4.512385, test error 51.42
# Epoch   900, train loss 0.001183, train error 0.00,  test loss 4.603817, test error 51.40
# Training model with 100 hidden variables
# Epoch     0, train loss 2.012035, train error 74.30,  test loss 1.947047, test error 74.35
# Epoch   100, train loss 0.089878, train error 0.22,  test loss 2.155843, test error 50.33
# Epoch   200, train loss 0.012183, train error 0.00,  test loss 3.006069, test error 51.05
# Epoch   300, train loss 0.005677, train error 0.00,  test loss 3.368253, test error 51.17
# Epoch   400, train loss 0.003536, train error 0.00,  test loss 3.597042, test error 51.42
# Epoch   500, train loss 0.002516, train error 0.00,  test loss 3.760836, test error 51.53
# Epoch   600, train loss 0.001927, train error 0.00,  test loss 3.890057, test error 51.47
# Epoch   700, train loss 0.001547, train error 0.00,  test loss 3.996979, test error 51.60
# Epoch   800, train loss 0.001286, train error 0.00,  test loss 4.086692, test error 51.65
# Epoch   900, train loss 0.001095, train error 0.00,  test loss 4.164512, test error 51.67
# Training model with 120 hidden variables
# Epoch     0, train loss 1.973720, train error 73.25,  test loss 1.898737, test error 73.55
# Epoch   100, train loss 0.052666, train error 0.00,  test loss 2.241025, test error 50.88
# Epoch   200, train loss 0.009622, train error 0.00,  test loss 2.886567, test error 50.85
# Epoch   300, train loss 0.004738, train error 0.00,  test loss 3.175702, test error 51.05
# Epoch   400, train loss 0.003030, train error 0.00,  test loss 3.364156, test error 51.17
# Epoch   500, train loss 0.002181, train error 0.00,  test loss 3.501573, test error 51.42
# Epoch   600, train loss 0.001684, train error 0.00,  test loss 3.611608, test error 51.25
# Epoch   700, train loss 0.001362, train error 0.00,  test loss 3.701676, test error 51.22
# Epoch   800, train loss 0.001136, train error 0.00,  test loss 3.779058, test error 51.28
# Epoch   900, train loss 0.000970, train error 0.00,  test loss 3.846727, test error 51.33
# Training model with 140 hidden variables
# Epoch     0, train loss 1.935833, train error 71.38,  test loss 1.850792, test error 71.45
# Epoch   100, train loss 0.037229, train error 0.00,  test loss 2.099130, test error 49.53
# Epoch   200, train loss 0.008163, train error 0.00,  test loss 2.579107, test error 49.40
# Epoch   300, train loss 0.004172, train error 0.00,  test loss 2.802498, test error 49.20
# Epoch   400, train loss 0.002709, train error 0.00,  test loss 2.951262, test error 48.95
# Epoch   500, train loss 0.001970, train error 0.00,  test loss 3.059851, test error 48.90
# Epoch   600, train loss 0.001531, train error 0.00,  test loss 3.146395, test error 48.65
# Epoch   700, train loss 0.001243, train error 0.00,  test loss 3.217764, test error 48.47
# Epoch   800, train loss 0.001040, train error 0.00,  test loss 3.278290, test error 48.55
# Epoch   900, train loss 0.000891, train error 0.00,  test loss 3.332042, test error 48.50
# Training model with 160 hidden variables
# Epoch     0, train loss 1.945311, train error 71.60,  test loss 1.884681, test error 72.22
# Epoch   100, train loss 0.028945, train error 0.00,  test loss 2.121425, test error 49.42
# Epoch   200, train loss 0.007249, train error 0.00,  test loss 2.523325, test error 49.10
# Epoch   300, train loss 0.003818, train error 0.00,  test loss 2.721064, test error 48.92
# Epoch   400, train loss 0.002507, train error 0.00,  test loss 2.853555, test error 49.00
# Epoch   500, train loss 0.001835, train error 0.00,  test loss 2.950943, test error 48.95
# Epoch   600, train loss 0.001431, train error 0.00,  test loss 3.029975, test error 49.08
# Epoch   700, train loss 0.001165, train error 0.00,  test loss 3.096009, test error 49.03
# Epoch   800, train loss 0.000977, train error 0.00,  test loss 3.152061, test error 49.10
# Epoch   900, train loss 0.000838, train error 0.00,  test loss 3.201712, test error 49.10
# Training model with 180 hidden variables
# Epoch     0, train loss 1.941593, train error 70.97,  test loss 1.850523, test error 72.85
# Epoch   100, train loss 0.023821, train error 0.00,  test loss 2.064833, test error 48.30
# Epoch   200, train loss 0.006518, train error 0.00,  test loss 2.421443, test error 48.28
# Epoch   300, train loss 0.003488, train error 0.00,  test loss 2.603401, test error 48.15
# Epoch   400, train loss 0.002315, train error 0.00,  test loss 2.722301, test error 48.20
# Epoch   500, train loss 0.001704, train error 0.00,  test loss 2.812776, test error 48.40
# Epoch   600, train loss 0.001336, train error 0.00,  test loss 2.884905, test error 48.35
# Epoch   700, train loss 0.001091, train error 0.00,  test loss 2.945600, test error 48.38
# Epoch   800, train loss 0.000918, train error 0.00,  test loss 2.997052, test error 48.47
# Epoch   900, train loss 0.000789, train error 0.00,  test loss 3.042372, test error 48.45
# Training model with 200 hidden variables
# Epoch     0, train loss 1.932423, train error 72.28,  test loss 1.842857, test error 71.62
# Epoch   100, train loss 0.020972, train error 0.00,  test loss 2.009526, test error 47.80
# Epoch   200, train loss 0.006037, train error 0.00,  test loss 2.321352, test error 48.05
# Epoch   300, train loss 0.003289, train error 0.00,  test loss 2.481604, test error 48.08
# Epoch   400, train loss 0.002196, train error 0.00,  test loss 2.590326, test error 48.10
# Epoch   500, train loss 0.001624, train error 0.00,  test loss 2.672561, test error 48.05
# Epoch   600, train loss 0.001277, train error 0.00,  test loss 2.739153, test error 47.97
# Epoch   700, train loss 0.001045, train error 0.00,  test loss 2.793912, test error 47.90
# Epoch   800, train loss 0.000880, train error 0.00,  test loss 2.841492, test error 47.80
# Epoch   900, train loss 0.000758, train error 0.00,  test loss 2.882539, test error 47.83
# Training model with 250 hidden variables
# Epoch     0, train loss 1.904523, train error 68.97,  test loss 1.837942, test error 71.00
# Epoch   100, train loss 0.016824, train error 0.00,  test loss 1.914518, test error 46.95
# Epoch   200, train loss 0.005306, train error 0.00,  test loss 2.168976, test error 46.58
# Epoch   300, train loss 0.002960, train error 0.00,  test loss 2.302805, test error 46.35
# Epoch   400, train loss 0.001998, train error 0.00,  test loss 2.397862, test error 46.28
# Epoch   500, train loss 0.001489, train error 0.00,  test loss 2.467738, test error 46.35
# Epoch   600, train loss 0.001175, train error 0.00,  test loss 2.525516, test error 46.47
# Epoch   700, train loss 0.000965, train error 0.00,  test loss 2.573228, test error 46.47
# Epoch   800, train loss 0.000815, train error 0.00,  test loss 2.613986, test error 46.42
# Epoch   900, train loss 0.000703, train error 0.00,  test loss 2.650371, test error 46.42
# Training model with 300 hidden variables
# Epoch     0, train loss 1.858953, train error 67.90,  test loss 1.788830, test error 70.15
# Epoch   100, train loss 0.014716, train error 0.00,  test loss 1.829605, test error 45.28
# Epoch   200, train loss 0.004849, train error 0.00,  test loss 2.046244, test error 45.10
# Epoch   300, train loss 0.002747, train error 0.00,  test loss 2.161479, test error 45.10
# Epoch   400, train loss 0.001868, train error 0.00,  test loss 2.240957, test error 45.17
# Epoch   500, train loss 0.001397, train error 0.00,  test loss 2.301486, test error 45.10
# Epoch   600, train loss 0.001107, train error 0.00,  test loss 2.350016, test error 45.12
# Epoch   700, train loss 0.000911, train error 0.00,  test loss 2.391038, test error 45.08
# Epoch   800, train loss 0.000771, train error 0.00,  test loss 2.425811, test error 45.10
# Epoch   900, train loss 0.000666, train error 0.00,  test loss 2.457108, test error 45.12
# Training model with 400 hidden variables
# Epoch     0, train loss 1.831239, train error 65.68,  test loss 1.766562, test error 69.12
# Epoch   100, train loss 0.011606, train error 0.00,  test loss 1.738966, test error 46.12
# Epoch   200, train loss 0.004151, train error 0.00,  test loss 1.908167, test error 45.88
# Epoch   300, train loss 0.002403, train error 0.00,  test loss 2.005558, test error 45.88
# Epoch   400, train loss 0.001655, train error 0.00,  test loss 2.071073, test error 45.62
# Epoch   500, train loss 0.001248, train error 0.00,  test loss 2.122207, test error 45.65
# Epoch   600, train loss 0.000994, train error 0.00,  test loss 2.164082, test error 45.67
# Epoch   700, train loss 0.000822, train error 0.00,  test loss 2.199608, test error 45.65
# Epoch   800, train loss 0.000697, train error 0.00,  test loss 2.229806, test error 45.62
# Epoch   900, train loss 0.000604, train error 0.00,  test loss 2.256315, test error 45.53

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
